# %%
import os
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # EDIT THOSE FILES

# %%
file_with_positions = "/home/laura/ANALYSIS/SNPTB/190624_Anotation_test/Annotation/position_test.txt"
file_with_annotation = "/home/laura/ANALYSIS/SNPTB/190624_Anotation_test/Annotation/HIS-25198169.combined.hf.annot.tsv"

# %% [markdown]
# ## Obtain and check positions

# %%
list_of_positions = []
with open(file_with_positions, 'r') as f:
    for line in f:
        list_of_positions.append(line.strip())
    while '' in list_of_positions : list_of_positions.remove('')
        
",".join(list_of_positions)
# Out:
# '1977,2532,7585,9143,9304,13460,14401,15117,17892,17913,17936,21819,23174,27416,27469,28640,34196,36538,37031,39758,42281,43945'

# %% [markdown]
# ## Select annotation fields to output

# %%
annot_df = pd.read_csv(file_with_annotation, sep="\t", header=0)

# %% [markdown]
# ### These are all the available fields

# %%
annot_df.columns
# Out:
# Index(['#CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT',
#        'sample', 'AC', 'af', 'AN', 'BaseQRankSum', 'DP', 'ExcessHet', 'FS',
#        'MQ', 'MQRankSum', 'QD', 'ReadPosRankSum', 'SOR', 'ANN', 'GT', 'AD',
#        'GQ', 'PL', 'Allele', 'Annotation', 'Annotation_Impact', 'Gene_Name',
#        'Gene_ID', 'Feature_Type', 'Feature_ID', 'Transcript_BioType', 'Rank',
#        'HGVS.c', 'HGVS.p', 'cDNA.pos / cDNA.length', 'CDS.pos / CDS.length',
#        'AA.pos / AA.length', 'Distance', 'PGT', 'PID', 'PS',
#        'ERRORS / WARNINGS / INFO', 'LOF', 'len_AD', 'REF_AD', 'ALT_AD', 'gt0',
#        'gt1', 'Gene length', 'AA length', 'dp', 'aF', 'AF', 'is_essential',
#        'is_polymorphic', 'product', 'drug_related', 'Lineage', 'Resistance'],
#       dtype='object')

# %%
annot_df.head(1)
# Out:
#        #CHROM   POS ID REF ALT     QUAL FILTER  \
# 0  Chromosome  1977  .   G   A  2420.24   PASS
#
#                                                 INFO          FORMAT  \
# 0  AC=2;AF=1.00;AN=2;BaseQRankSum=0.548;DP=28;Exc...  GT:AD:DP:GQ:PL
#
#                     sample   AC   af   AN  BaseQRankSum    DP  ExcessHet   FS  \
# 0  1/1:0,28:28:82:948,82,0  2.0  1.0  2.0         0.548  28.0     0.1902  0.0
#
#      MQ  MQRankSum     QD  ReadPosRankSum    SOR  \
# 0  60.0        0.0  34.09           0.686  1.981
#
#                                                  ANN   GT    AD    GQ  \
# 0  A|intergenic_region|MODIFIER|dnaA-dnaN|Rv0001-...  1/1  0,28  82.0
#
#          PL Allele         Annotation Annotation_Impact  Gene_Name  \
# 0  948,82,0      A  intergenic_region          MODIFIER  dnaA-dnaN
#
#          Gene_ID       Feature_Type     Feature_ID Transcript_BioType Rank  \
# 0  Rv0001-Rv0002  intergenic_region  Rv0001-Rv0002                NaN  NaN
#
# ...

# %% [markdown]
# ### Select only those you need

# %%
columns = ['#CHROM', 'POS', 'ID', 'REF', 'ALT', 'Annotation', 'Annotation_Impact', 'Gene_Name',
       'Gene_ID', 'Feature_Type', 'Feature_ID', 'Transcript_BioType', 'Rank',
       'HGVS.c', 'HGVS.p', 'cDNA.pos / cDNA.length', 'CDS.pos / CDS.length',
       'AA.pos / AA.length', 'Gene length', 'AA length',
        'is_essential','is_polymorphic', 'product', 'drug_related', 'Lineage', 'Resistance']

# %%
#annot_df[columns][((annot_df["REF"].str.len() < 2) | (annot_df["ALT"].str.len() < 2)) & (annot_df["POS"].isin(list_of_positions))]

# %%
filtered_annotated_table = annot_df[columns][annot_df["POS"].isin(list_of_positions)]
filtered_annotated_table
# Out:
#         #CHROM    POS ID REF ALT          Annotation Annotation_Impact  \
# 0   Chromosome   1977  .   G   A   intergenic_region          MODIFIER
# 1   Chromosome   2532  .   C   T  synonymous_variant               LOW
# 2   Chromosome   7585  .   C   G  synonymous_variant               LOW
# 3   Chromosome   9143  .   C   T  synonymous_variant               LOW
# 4   Chromosome   9304  .   A   G  synonymous_variant               LOW
# 5   Chromosome  13460  .   G   A  synonymous_variant               LOW
# 6   Chromosome  14401  .   G   A  synonymous_variant               LOW
# 7   Chromosome  15117  .   G   C  synonymous_variant               LOW
# 8   Chromosome  17892  .   G   A    missense_variant          MODERATE
# 9   Chromosome  17913  .   T   C    missense_variant          MODERATE
# 10  Chromosome  17936  .   G   A    missense_variant          MODERATE
# 11  Chromosome  21819  .   C   A  synonymous_variant               LOW
# ...

# %%
output_file_name = ".".join(file_with_annotation.split(".")[0:-1]) + ".filterd.tsv"


filtered_annotated_table.to_csv(output_file_name, sep='\t', index=False)
